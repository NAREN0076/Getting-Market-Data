# %%
import pandas as pd

import yfinance as yf

# %%
price_data_apple = yf.download("AAPL",start="2019-01-01",auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price_data_apple.tail()
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2024-05-13  185.440002  187.100006  184.619995  186.279999  72044800
# 2024-05-14  187.509995  188.300003  186.289993  187.429993  52393600
# 2024-05-15  187.910004  190.649994  187.369995  189.720001  70400000
# 2024-05-16  190.470001  191.100006  189.660004  189.839996  52845200
# 2024-05-17  189.509995  190.809998  189.179993  189.869995  41260800

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

#plot the close price 
plt.figure(figsize=(15,7))
price_data_apple['Close'].plot()

#set the title and axis label 
plt.title('Apple price data', fontsize=14)
plt.xlabel('year-Month', fontsize=12)
plt.ylabel('price', fontsize=12)

# show the plot 
plt.show()
